# %%
import cv2 as cv

# %%
from matplotlib import pyplot as plt

# %%
faceCascade = cv.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
img = cv.imread('/home/zews/Pictures/thanos.png')

# %%
plt.imshow(imgGray)

# %%
imgGray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
faces = faceCascade.detectMultiScale(imgGray,1.3, 5)
# param(image, scale , minimum neighnour)

# %%
faceCascade

# %%
capture = cv.VideoCapture('/home/zews/Downloads/Infinitix.mp4')

# %%
capture = cv.VideoCapture(0)

# %%
while True:
    # extracting the frames 
    ret, frame = capture.read()
    # converting to gray-scale 
    gray = cv2.cvtColor(frame, cv.COLOR_BGR2GRAY)

# %%
for (x,y,w,h) in faces:
    cv.rectangle(img, (x,y),(x+w,y+h),(255,0,0),2)

# %%
# when capture is working
while capture.isOpened():
#     capture frame by frame
    success, frame = capture.read()
    if success == True:
#         flipcode = 0: flip vertically
#         flipcode > 0: flip horizontally
#         flipcode < 0: flip vertically and horizontally
#         frame = cv.flip(frame,1)
        gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
        faces = faceCascade.detectMultiScale(gray,1.3, 5)
        for (x,y,w,h) in faces:
            cv.rectangle(frame, (x,y),(x+w,y+h),(255,0,0),2)
            
            
        cv.imshow('video',frame)
    #     waitkey(speed) lower the value higher the speed because it is the delay time for each frame.
        key = cv.waitKey(25)
        if key == 27:
            break
    else:
        print('Can not recieve frame')
        break

# when everything is done
capture.release()
cv.destroyAllWindows()

# %%
plt.imshow(img)

# %%
cv.imshow("face detection",img)
key = cv.waitKey(0) # This is necessary to be required so that the image doesn't close immediately
if key == 27:
    cv.destroyAllWindows()
